# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import fetch_california_housing
california = fetch_california_housing()

# %%
california.DESCR
# Out:
# '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block\n        - HouseAge      median house age in block\n        - AveRooms      average number of rooms\n        - AveBedrms     average number of bedrooms\n        - Population    block population\n        - AveOccup      average house occupancy\n        - Latitude      house block latitude\n        - Longitude     house block longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttp://lib.stat.cmu.edu/datasets/\n\nThe target variable is the median house value for California districts.\n\nThis dataset was derived from the 1990 U.S. census, using one row per census\nblock group. A block group is the smallest geographical un
# ...

# %%
df = pd.DataFrame(california.data, columns=california.feature_names)
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
# MedInc        20640 non-null float64
# HouseAge      20640 non-null float64
# AveRooms      20640 non-null float64
# AveBedrms     20640 non-null float64
# Population    20640 non-null float64
# AveOccup      20640 non-null float64
# Latitude      20640 non-null float64
# Longitude     20640 non-null float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
value = pd.DataFrame(california.target, columns=["MedVal"])
value.head()
# Out:
#    MedVal
# 0   4.526
# 1   3.585
# 2   3.521
# 3   3.413
# 4   3.422

# %%
value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 1 columns):
# MedVal    20640 non-null float64
# dtypes: float64(1)
# memory usage: 161.3 KB

# %%
value.describe()
# Out:
#              MedVal
# count  20640.000000
# mean       2.068558
# std        1.153956
# min        0.149990
# 25%        1.196000
# 50%        1.797000
# 75%        2.647250
# max        5.000010

# %%
income = df["MedInc"]
plt.scatter(income, value, s=5)
plt.title("Median Income vs. Median House Value")
plt.xlabel("Median Income")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
age = df["HouseAge"]
plt.scatter(age, value, s=5)
plt.title("House Age vs. Median House Value")
plt.xlabel("House Age")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
rooms = df["AveRooms"]
zoom = plt.scatter(rooms, value, s=5)
plt.title("Average Number of Rooms vs. Median House Value")
plt.xlabel("Rooms")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
rooms = df["AveRooms"]
zoom = plt.scatter(rooms, value, s=5)
plt.title("Average Number of Rooms vs. Median House Value -Zoomed In")
plt.xlabel("Rooms")
plt.ylabel("Median House Value")
plt.axis([0,10,0,5])
# Out:
# [0, 10, 0, 5]

# %%
bedRooms = df["AveBedrms"]
plt.scatter(bedRooms, value, s=5)
plt.title("Average Number of Bedrooms vs. Median House Value")
plt.xlabel("Bedrooms")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
bedRooms = df["AveBedrms"]
plt.scatter(bedRooms, value, s=5)
plt.title("Average Number of Bedrooms vs. Median House Value -Zoomed In")
plt.xlabel("Bedrooms")
plt.ylabel("Median House Value")
plt.axis([0.5,2.0,0,5])
# Out:
# [0.5, 2.0, 0, 5]

# %%
pop = df["Population"]
plt.scatter(pop, value, s=5)
plt.title("Block Population vs. Median House Value")
plt.xlabel("Population")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
pop = df["Population"]
plt.scatter(pop, value, s=5)
plt.title("Block Population vs. Median House Value -Zoomed In")
plt.xlabel("Population")
plt.ylabel("Median House Value")
plt.axis([0,6000,0,5])
# Out:
# [0, 6000, 0, 5]

# %%
occup = df["AveOccup"]
plt.scatter(occup, income, s=5)
plt.title("Average House Occupation vs. Median House Value")
plt.xlabel("Occupation")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
occup = df["AveOccup"]
plt.scatter(occup, income, s=5)
plt.title("Average House Occupancy vs. Median House Value -Zoomed In")
plt.xlabel("Occupancy")
plt.ylabel("Median House Value")
plt.axis([0,7.5,0,5])
# Out:
# [0, 7.5, 0, 5]

# %%
lat = df["Latitude"]
plt.scatter(lat, income, s=5)
plt.title("House Block Latitude vs. Median House Value")
plt.xlabel("Latitude")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
long = df["Longitude"]
plt.scatter(long, income, s=5)
plt.title("House Block Longitude vs. Median House Value")
plt.xlabel("Longitude")
plt.ylabel("Median House Value")
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df, value, test_size = 0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([[ 4.33333407e-01,  9.29324337e-03, -9.86433739e-02,
#          5.93215487e-01, -7.56192502e-06, -4.74516383e-03,
#         -4.21449336e-01, -4.34166041e-01]])

# %%
predict = lr.predict(X_test)

# %%
linear = np.arange(0, 6)
linear
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
plt.scatter(y_test, predict, s=5)
plt.plot(linear, color="red")
plt.title("Default Linear Regression With All Parameters")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
rmse = np.sqrt(mean_squared_error(y_test, predict))
r2 = r2_score(y_test, predict)
print(rmse)
print(r2)
lr.score(X_test, y_test)
# Out:
# 0.7273129773603123
# 0.5943232652466193
# 0.5943232652466193

# %%
pred_train = lr.predict(X_train)
plt.scatter(y_train, pred_train, s=5)
plt.plot(linear, color="red")
plt.title("Linear model on its Training Data")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
rmse = np.sqrt(mean_squared_error(y_train, pred_train))
r2 = r2_score(y_train, pred_train)
print(rmse)
print(r2)
lr.score(X_train, y_train)
# Out:
# 0.7234924745376035
# 0.6088968118672871
# 0.6088968118672871

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_featuresd2= PolynomialFeatures(degree=2)
x_train_polyd2 = polynomial_featuresd2.fit_transform(X_train)

polyd2_lr = LinearRegression()
polyd2_lr.fit(x_train_polyd2, y_train)
x_test_polyd2 = polynomial_featuresd2.fit_transform(X_test)
poly_predd2 = polyd2_lr.predict(x_test_polyd2)

# %%
plt.scatter(y_test, poly_predd2, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 2")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, poly_predd2, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 2 zoomed in")
plt.xlabel("Actual")
plt.ylabel("Prediction")
plt.axis([0,5.5,-10,10])
# Out:
# [0, 5.5, -10, 10]

# %%
rmse = np.sqrt(mean_squared_error(y_test, poly_predd2))
r2 = r2_score(y_test, poly_predd2)
print(rmse)
print(r2)
# Out:
# 1.6624819265305444
# -1.1195872273913303

# %%
poly_predd2_train = polyd2_lr.predict(x_train_polyd2)
plt.scatter(y_train, poly_predd2_train, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial model with degree 2 on its Training Data")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
rmse = np.sqrt(mean_squared_error(y_train, poly_predd2_train))
r2 = r2_score(y_train, poly_predd2_train)
print(rmse)
print(r2)
# Out:
# 0.6478426079571845
# 0.6864099059497185

# %%
polynomial_featuresd3= PolynomialFeatures(degree=3)
x_train_polyd3 = polynomial_featuresd3.fit_transform(X_train)

polyd3_lr = LinearRegression()
polyd3_lr.fit(x_train_polyd3, y_train)
x_test_polyd3 = polynomial_featuresd3.fit_transform(X_test)
poly_predd3 = polyd3_lr.predict(x_test_polyd3)

# %%
plt.scatter(y_test, poly_predd3, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 3")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, poly_predd3, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 3 zoomed in")
plt.xlabel("Actual")
plt.ylabel("Prediction")
plt.axis([0,5.5,-10,10])
# Out:
# [0, 5.5, -10, 10]

# %%
rmse = np.sqrt(mean_squared_error(y_test, poly_predd3))
r2 = r2_score(y_test, poly_predd3)
print(rmse)
print(r2)
# Out:
# 542.638745351108
# -225817.24527328805

# %%
poly_predd3_train = polyd3_lr.predict(x_train_polyd3)
plt.scatter(y_train, poly_predd3_train, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial model with degree 3 on its Training Data")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
rmse = np.sqrt(mean_squared_error(y_train, poly_predd3_train))
r2 = r2_score(y_train, poly_predd3_train)
print(rmse)
print(r2)
# Out:
# 0.5897913932491953
# 0.7400916804887363

# %%
polynomial_featuresd4= PolynomialFeatures(degree=4)
x_train_polyd4 = polynomial_featuresd4.fit_transform(X_train)

polyd4_lr = LinearRegression()
polyd4_lr.fit(x_train_polyd4, y_train)
x_test_polyd4 = polynomial_featuresd4.fit_transform(X_test)
poly_predd4 = polyd4_lr.predict(x_test_polyd4)

# %%
plt.scatter(y_test, poly_predd4, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 4")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, poly_predd4, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 4")
plt.xlabel("Actual")
plt.ylabel("Prediction")
plt.axis([0,5.5,-10,10])
# Out:
# [0, 5.5, -10, 10]

# %%
rmse = np.sqrt(mean_squared_error(y_test, poly_predd4))
r2 = r2_score(y_test, poly_predd4)
print(rmse)
print(r2)
# Out:
# 14422.791871348096
# -159527698.1519827

# %%
poly_predd4_train = polyd4_lr.predict(x_train_polyd4)
plt.scatter(y_train, poly_predd4_train, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial model with degree 4 on its Training Data")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
rmse = np.sqrt(mean_squared_error(y_train, poly_predd4_train))
r2 = r2_score(y_train, poly_predd4_train)
print(rmse)
print(r2)
# Out:
# 0.5739833396522552
# 0.7538375002009519

# %%
polynomial_featuresd5= PolynomialFeatures(degree=5)
x_train_polyd5 = polynomial_featuresd5.fit_transform(X_train)

polyd5_lr = LinearRegression()
polyd5_lr.fit(x_train_polyd5, y_train)
x_test_polyd5 = polynomial_featuresd5.fit_transform(X_test)
poly_predd5 = polyd5_lr.predict(x_test_polyd5)

# %%
plt.scatter(y_test, poly_predd5, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 5")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
plt.scatter(y_test, poly_predd5, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial Regression with degree 5")
plt.xlabel("Actual")
plt.ylabel("Prediction")
plt.axis([0,5.5,-10,10])
# Out:
# [0, 5.5, -10, 10]

# %%
rmse = np.sqrt(mean_squared_error(y_test, poly_predd5))
r2 = r2_score(y_test, poly_predd5)
print(rmse)
print(r2)
# Out:
# 176236.90611564487
# -23819418156.850388

# %%
poly_predd5_train = polyd5_lr.predict(x_train_polyd5)
plt.scatter(y_train, poly_predd5_train, s=5)
plt.plot(linear, color="red")
plt.title("Polynomial model with degree 5 on its Training Data")
plt.xlabel("Actual")
plt.ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
rmse = np.sqrt(mean_squared_error(y_train, poly_predd5_train))
r2 = r2_score(y_train, poly_predd5_train)
print(rmse)
print(r2)
# Out:
# 0.58721982563692
# 0.7423532079711035

# %%
from sklearn.model_selection import cross_val_score

# %%
lr_cross_score = cross_val_score(lr, df, value, cv=10)

# %%
print(sum(lr_cross_score)/len(lr_cross_score))
print(lr_cross_score)
# Out:
# 0.5110068610524559
# [0.48254494 0.61416063 0.42274892 0.48178521 0.55705986 0.5412919
#  0.47496038 0.45844938 0.48177943 0.59528796]

# %%
polynomial_featuresd2= PolynomialFeatures(degree=2)
x_polyd2 = polynomial_featuresd2.fit_transform(california.data)
polyd2_cross_score = cross_val_score(polyd2_lr, x_polyd2, value, cv=10)

# %%
print(np.mean(polyd2_cross_score))
print(polyd2_cross_score)
# Out:
# -0.43579974706045876
# [ 0.50688988 -0.40538862  0.56077475  0.51974671  0.50645854  0.59570878
#   0.38279432  0.53050525  0.51002428 -8.06551135]

# %%
polynomial_featuresd3= PolynomialFeatures(degree=3)
x_polyd3 = polynomial_featuresd3.fit_transform(california.data)
polyd3_cross_score = cross_val_score(polyd3_lr, x_polyd3, value, cv=10)

# %%
print(np.mean(polyd3_cross_score))
print(polyd3_cross_score)
# Out:
# -236704.01813336607
# [-2.59079771e+01 -4.88644597e+03  6.57955934e-01  5.83864925e-01
#  -4.03990857e+00  1.27445361e-01 -3.09838379e+02 -1.67235154e-01
#  -1.45635069e+02 -2.36166952e+06]

# %%
polynomial_featuresd4= PolynomialFeatures(degree=4)
x_polyd4 = polynomial_featuresd4.fit_transform(california.data)
polyd4_cross_score = cross_val_score(polyd4_lr, x_polyd4, value, cv=10)

# %%
print(np.mean(polyd4_cross_score))
print(polyd4_cross_score)
# Out:
# -708007192.773464
# [-1.26276663e+04 -4.11630637e+07  2.10809702e-01  4.78640586e-01
#  -1.22588585e+03 -3.59560019e+00 -5.41145734e+03 -7.88448452e+01
#  -1.86517183e+07 -7.02023780e+09]

# %%
polynomial_featuresd5= PolynomialFeatures(degree=5)
x_polyd5 = polynomial_featuresd5.fit_transform(california.data)
polyd5_cross_score = cross_val_score(polyd5_lr, x_polyd5, value, cv=10)

# %%
print(np.mean(polyd5_cross_score))
print(polyd5_cross_score)
# Out:
# -9892758500.080694
# [-1.41018709e+02 -2.82358685e+07  5.15399061e-01  5.56904865e-01
#  -7.58624459e+04 -4.84242874e+01 -9.50261912e+06 -6.44142783e+00
#  -9.38727978e+08 -9.79510425e+10]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
df.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
data = df.copy()
data['MedVal'] = value.copy()['MedVal'] # combining input and output into one table
train_data = data.sample(frac=0.8, random_state=0)
test_data = data.drop(train_data.index)

# %%
train_labels = train_data.copy()['MedVal']
test_labels = test_data.copy()['MedVal']

# %%
train_data = train_data.drop('MedVal', axis=1)
test_data = test_data.drop('MedVal', axis=1)

# %%
norm_test_data = (test_data - test_data.describe().transpose()['mean']) / test_data.describe().transpose()['std']
norm_train_data = (train_data - train_data.describe().transpose()['mean']) / train_data.describe().transpose()['std']

# %%
len(california.target)
# Out:
# 20640

# %%
def build_model():
    model = keras.Sequential([
        layers.Dense(8, activation='relu', input_shape=[len(norm_train_data.keys())]),
        layers.Dense(4, activation='relu'),
        #layers.Dense(4, activation='relu'),
        layers.Dense(1)
    ])
    
    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse',
                optimizer= optimizer,
                metrics=['mae', 'mse'])
    return model

# %%
nn_model = build_model()

# %%
nn_model.summary()
# Out:
# Model: "sequential_58"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_174 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dense_175 (Dense)            (None, 4)                 36
# _________________________________________________________________
# dense_176 (Dense)            (None, 1)                 5
# ...
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________

# %%
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

EPOCHS = 250

history = nn_model.fit(
    norm_train_data, train_labels,
    epochs=EPOCHS, validation_split=0.2, verbose=0,
    callbacks=[PrintDot()])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# ....................................................................................................
# ....................................................................................................
# ..................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 245  0.301755  0.375309  0.301755  0.308620  0.376358  0.308620    245
# 246  0.302961  0.375401  0.302961  0.311157  0.379475  0.311157    246
# 247  0.305792  0.375619  0.305792  0.314504  0.375542  0.314504    247
# 248  0.304640  0.375747  0.304640  0.310581  0.376985  0.310581    248
# 249  0.304137  0.375912  0.304137  0.310013  0.377317  0.310013    249

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch
    
    plt.figure()
    plt.title('Mean Absolute Error vs. Number of Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Absolute Error [MEDV]')
    plt.plot(hist['epoch'], hist['mae'],
            label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'],
            label='Val Error')
    plt.ylim([0,3])
    plt.legend()
    
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [MEDV^2]')
    plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
    plt.ylim([0,3])
    plt.legend()
    plt.show()
    
plot_history(history)

# %%
loss, mae, mse = nn_model.evaluate(norm_test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f}".format(mae))
print("Testing set Mean Squared Error: {:5.2f}".format(mse)) #ideally would be lower than 0.53
print("Testing set Root Mean Squared Error: {:5.2f}".format(np.sqrt(mse))) #ideally would be lower than 0.78
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 4128/4128 - 0s - loss: 6.4397 - mae: 1.7468 - mse: 6.4397
# Testing set Mean Abs Error:  1.75
# Testing set Mean Squared Error:  6.44
# Testing set Root Mean Squared Error:  2.54

# %%
test_predictions = nn_model.predict(norm_test_data).flatten()

#a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions, s=3)
plt.xlabel('Actual Median Values [in $1000s]')
plt.ylabel('Predicted Median Values [in $1000s]')
#lims = [0, 6]
plt.xlim([0, 6])
#plt.ylim([0, 10])
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
# Now try training model with early stop to get number of epochs correct
nn_model_es = build_model()

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history_es = nn_model_es.fit(norm_train_data, train_labels, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history_es)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# ....................................................................

# %%
loss, mae, mse = nn_model_es.evaluate(norm_test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f}".format(mae))
print("Testing set Mean Squared Error: {:5.2f}".format(mse)) #ideally would be lower than 0.53
print("Testing set Root Mean Squared Error: {:5.2f}".format(np.sqrt(mse))) #ideally would be lower than 0.78
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 4128/4128 - 0s - loss: 21.4198 - mae: 2.9270 - mse: 21.4198
# Testing set Mean Abs Error:  2.93
# Testing set Mean Squared Error: 21.42
# Testing set Root Mean Squared Error:  4.63

# %%
test_predictions = nn_model_es.predict(norm_test_data).flatten()

#a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions, s=3)
plt.xlabel('Actual Median Values [in $1000s]')
plt.ylabel('Predicted Median Values [in $1000s]')
plt.xlim([0, 6])
#plt.ylim([0, 10])
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %% [markdown]
# ### Going to try using non-normalized data

# %%
def build_model2():
    model = keras.Sequential([
        layers.Dense(64, activation='relu', input_shape=[len(norm_train_data.keys())]),
        layers.Dense(4, activation='relu'),
        #layers.Dense(4, activation='relu'),
        layers.Dense(1)
    ])
    
    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse',
                optimizer= optimizer,
                metrics=['mae', 'mse'])
    return model

# %%
nn_model2 = build_model()

# %%
nn_model2.summary()
# Out:
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_189 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dense_190 (Dense)            (None, 4)                 36
# _________________________________________________________________
# dense_191 (Dense)            (None, 1)                 5
# ...
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________

# %%
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

EPOCHS = 500

history = nn_model2.fit(
    train_data, train_labels,
    epochs=EPOCHS, validation_split=0.2, verbose=0,
    callbacks=[PrintDot()])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 495  0.538142  0.544463  0.538143  0.529118  0.529766  0.529118    495
# 496  0.534634  0.542954  0.534634  0.633483  0.616789  0.633483    496
# 497  0.536141  0.544843  0.536141  0.544705  0.532668  0.544705    497
# 498  0.537409  0.545062  0.537409  0.523596  0.532334  0.523596    498
# 499  0.537537  0.544451  0.537537  0.524062  0.539667  0.524062    499

# %%
plot_history(history)

# %%
loss, mae, mse = nn_model2.evaluate(test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f}".format(mae))
print("Testing set Mean Squared Error: {:5.2f}".format(mse)) #ideally would be lower than 0.53
print("Testing set Root Mean Squared Error: {:5.2f}".format(np.sqrt(mse))) #ideally would be lower than 0.78
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 4128/4128 - 0s - loss: 0.4921 - mae: 0.5361 - mse: 0.4921
# Testing set Mean Abs Error:  0.54
# Testing set Mean Squared Error:  0.49
# Testing set Root Mean Squared Error:  0.70

# %%
test_predictions = nn_model2.predict(test_data).flatten()

#a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions, s=3)
plt.xlabel('Actual Median Values [in $1000s]')
plt.ylabel('Predicted Median Values [in $1000s]')
#lims = [0, 6]
plt.xlim([0, 6])
#plt.ylim([0, 10])
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
# Now try training model with early stop to get number of epochs correct
nn_model_es2 = build_model2()

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)

history_es = nn_model_es2.fit(train_data, train_labels, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history_es)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# ....................................................................................................
# ....................................................................................................
# .........................

# %%
loss, mae, mse = nn_model_es2.evaluate(test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f}".format(mae))
print("Testing set Mean Squared Error: {:5.2f}".format(mse)) #ideally would be lower than 0.53
print("Testing set Root Mean Squared Error: {:5.2f}".format(np.sqrt(mse))) #ideally would be lower than 0.78
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 4128/4128 - 0s - loss: 0.4302 - mae: 0.5004 - mse: 0.4302
# Testing set Mean Abs Error:  0.50
# Testing set Mean Squared Error:  0.43
# Testing set Root Mean Squared Error:  0.66

# %%
test_predictions = nn_model_es2.predict(test_data).flatten()

#a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions, s=3)
plt.xlabel('Actual Median Values [in $1000s]')
plt.ylabel('Predicted Median Values [in $1000s]')
plt.xlim([0, 6])
#plt.ylim([0, 10])
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %% [markdown]
# ### Seems to perform better with non-normalized data
